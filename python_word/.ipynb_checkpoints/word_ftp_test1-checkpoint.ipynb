# %%
# Copyright(C) 2020 刘珅珅
# Environment: python 3.7
# Date: 2020.8.7
# 所有doc文件转换docx
import os
import re
import datetime
import ftplib
import config

# %%
def ftp_connect():
    ''' 连接ftp '''
    ftp = ftplib.FTP()  
    ftp.set_pasv(True)

    try:
        ftp.connect(config.FTP_SERVER,21)
        print(ftp.welcome)
    except (socket.error, socket.gaierror) as e:
        print ("Error: connect ftpserver '%s' failed! %s") % (config.FTP_SERVER, e)
        exit()

    try:
        ftp.login(config.FTP_USER,config.FTP_PWD)  
        ftp.encoding = "utf-8"
        print("ftp://{0} login successfully!".format(config.FTP_SERVER))
    except(ftplib.error_perm) as e:
        print("Error: login failed, error code: {0}".format(e))
        exit()

    return ftp

# %%
def ftp_down(ftp, local_filepath, remote_filename):
    if not os.path.exists(local_filepath):
        os.mkdir(local_filepath)
    buf_size = 1024
    filename = os.path.basename(remote_filename)
    dirname = os.path.dirname(remote_filename)
    local_filename = local_filepath + '/' + filename
    ftp.cwd(dirname)
    ftp_list = ftp.nlst()
    if filename in ftp_list:
        if not os.path.exists(local_filename):
            with open(local_filename, 'wb') as file_handler:
                ftp.retrbinary('retr {0}'.format(filename), file_handler.write)
            print(filename + "下载成功")

    else:
        print(filename + " not exist")

# %%
def traverse(folder_path, target, local_path):
    fs = os.listdir(folder_path)
    delete_files = []
    ftp = ftp_connect()
    try:
        for f in fs:
            tmp_path = os.path.join(folder_path, f)
            with open(tmp_path, 'r', encoding='utf-8') as file_obj:
                lines = file_obj.readlines()
                tmps = [line for line in lines if '开始bin文件转换' in line or '开始wmf文件转换' in line]
                if len(tmps) > 0:
                    delete_files.append(tmp_path)
                else:
                    tmps = [line for line in lines if target in line]
                    if len(tmps) > 0:
                        print('找到' + target)
                        tmps = [line for line in lines if '开始下载文件' in line]
                        if len(tmps) > 0:
                            ftp_filepath = tmps[0].split(':21')[1]
                            print('下载文件' + ftp_filepath)
                            ftp_down(ftp,local_path, ftp_filepath.strip())

        [os.remove(file) for file in delete_files]
    except Exception as e:
        print(e)
        pass
    ftp.quit()

# %%
traverse(r'C:\Users\Zhao.LJ\Downloads\20200916', 'log22', r'C:\Users\Zhao.LJ\Downloads\文本框组合')
# Out:
# 220 (vsFTPd 3.0.2)
# ftp://ftp3.dc2.fzyun.io login successfully!
# 找到log22
# 下载文件/data/2020-09-16/a3a2bca4-2/66ddec0a6b36442a85dff835a452df72.docx
#
# ['66ddec0a6b36442a85dff835a452df72.zip']
# 66ddec0a6b36442a85dff835a452df72.docx not exist
# 找到log22
# 下载文件/FounderDeployPackage/dongyan/word/xml自动测试book/Book34.docx
#
大学出版社）.docx', '适合（需优化）遗传流行病学v2胡永华（协和医科大学出版社）（章节）.docx', '适合（需完善结构化）完美的劳动关系-人力资源和社会保障实务应用全流程风险防控（原）云南大学出版社 篇章节 适合 但这种篇标题识别不出来.docx', '适合（需预处理文本框）中国烟草流行与控制（姜垣）（协和医科大学出版社）（章节）.docx', '适合（需预处理装饰图）重点-临床指导1 全（协和医科大学出版社）（篇章节）.docx', '适合（需预处理）5.板块4第三章关联研究相关的多变量统计方法20180222（协和医科大学出版社）（章节）.docx', '适合（需预处理）现场流行病学公共卫生选题实践-王兆南（协和医科大学出版社）（无正文）.docx', '适合（需预处理）肿瘤流行病-zyq乔友林0226（协和医科大学出版社）（章节）.doc']
# 适合 古 骆 天 音 云南大学出版社（章节）.doc下载成功
# 找到log22
# 下载文件/FounderDeployPackage/dongyan/word/005教材/适合_第八章时序逻辑电路(华中科技大学出版社)(章、8.1).docx
#
# ['适合 Visual Basic程序设计（第3版）原稿（国开大学出版社）.docx', '适合 外汇交易：理论、实务、案例、实训-刘伟-终审（东北财经大学出版社）.docx', '适合 外贸业务实战基础教程（合稿新）-雷云.doc', '适合 工作分析与应用（第四版  待终审）（东北财经大学出版社）.docx', '适合 税务机关突发事件应对(付立红)待终审（东北财经大学出版社）.docx', '适合 绩效管理-严伟-二版-终审后（东北财经大学出版社）.docx', '适合 （效果不佳）纳税实务终审后（东北财经大学出版社）.docx', '适合_C#程序设计——Visual C#2013原理与应用（作者稿）（国开大学出版社）.docx', '适合_CC++语言程序设计 01扉页(华中科技大学出版社).doc', '适合_CC++语言程序设计 02前言(华中科技大学出版社).doc', '适合_CC++语言程序设计 03目录(华中科技大学出版社).doc', '适合_CC++语言程序设计04(第1-12章)(华中科技大学出版社)(章、1.1).doc', '适合_DC-001-（待复审）-团队拓展训练教程（3版）（东北财经大学出版社）.docx', '适合_DC-003-《网络广告学》（待终审）（东北财经大学出版社）.docx', '适合_健康评估(河南科技出版社)(章、一)不含篇.docx', '适合_医学伦理学与卫生法规书稿5-1120180620092103(河南科技出版社)(篇、章、节、一).docx', '适合_医药营销技术最终定稿(华中科技大学出版社)(项目-模块-任务).docx', '适合_大学语文(朱)(定稿)改(华中科技大学出版社)(篇-第一单元-一).docx', '适合_天然药物提取分离技术(河南科技出版社)(项目-任务).docx', '适合_应用统计学定稿版1(华中科技大学出版社)(不含篇).docx', '适合_急危重症护理学(原稿)(河南科技出版社)(不含篇).docx', '适合_机电传动与控制技术(华中科技大学出版社)(章-1.1).docx', '适合_河南科技-立体化教材：美学理论与艺术鉴赏-20191019(加图标版)(河南科技出版社)(不含篇).docx', '适合_流体力学（哈尔滨工程大学出版社）(不含篇).doc', '适合_王付经方使用手册12.26(三审后定稿新)-副本2(河南科技出版社)(章节一)不含篇.docx', '适合_生理学全篇20180511072448(河南科技出版社)（章、节、一）(不含篇).docx', '适合_病理学(河南科技出版社)(不含篇).docx', '适合_税费计算与缴纳（东北财经大学出版社）.docx', '适合_穴位贴敷疗法(河南科技出版社)（篇章节）.docx', '适合_第八章时序逻辑电路(华中科技大学出版社)(章、8.1).docx', '适合_管理基础与实务-胡培业(华中科技大学出版社)(模块-项目).doc', '适合_管理学基础（原稿）（国开大学出版社）_适合.docx', '适合_纳秒脉冲技术的医学应用(上)(河南科技出版社)(章、节、一)不含篇.docx', '适合_纳秒脉冲技术的医学应用(下)(河南科技出版社)(章、节、一)不含篇.docx', '适合_线性空间-文前(哈尔滨工程大学出版社)(不含篇).docx', '适合_线性空间-正文(哈尔滨工程大学出版社)(不含篇).docx', '适合_高等统计物理学(哈尔滨工程大学出版社)(不含篇)教材.docx', '适合_黄河水院水工建筑物(河南科技出版社)(不含篇)教材.docx', '适合（答案部分不好）专升本数学教材10.8（沈阳姿兰）（章节）.docx', '适合（答案部分不好）数学图书（沈阳姿兰）.doc', '适合（需预处理)_DC-004-10.10管理会计-周频-（第二版）（终审后）（东北财经大学出版社）.docx', '适合（需预处理）马桂顺《旅游企业会计》主教材（高职六版）（待通读）（东北财经大学出版社）.docx']
# 适合_第八章时序逻辑电路(华中科技大学出版社)(章、8.1).docx下载成功
# 找到log22
# 下载文件/FounderDeployPackage/dongyan/word/bug/（幼教部）编纂系统-万能工匠儿童创造力培养指导手册.docx
#
# ['GB 2763-2018-报批稿.doc', '傅里叶变化及其在信息处理中的应用.doc', '地质矿产与生态环境-平台+复审版本20200807031516.docx', '第九章 中药质量控制与分析相关国内外数据库简介及使用.docx', '管理基础与实务-胡培业.docx', '精细分层注水技术 20190402终稿.doc', '精英的黄昏.doc', '系统与软件工程系统与软件质量要求和评价(SQuaRE).doc', '纳秒脉冲技术的医学应用（上）.docx', '美国疾控中心关于2019年新型冠状病毒的指导意见3.0版本2-12.docx', '跨页表中有图片.docx', '近代余杭经济资料选辑1.doc', '道路材料应用技术(2017.6.13).doc', '附件2植物源性食品中90种有机磷类农药及其代谢物残留量的测定-气相色谱法-标准文本（报批稿2018.10）.docx', '马桂顺《旅游企业会计》主教材（高职六版）（待通读）.docx', '高等统计物理学-正文.docx', '黄河水院 水工建筑物 .docx', '龙王庙专著汇总稿-终.doc', '（定稿）辽宁省无资料地区河流设计暴雨洪水计算0306.docx', '（幼教部）编纂系统-万能工匠儿童创造力培养指导手册.docx']
# （幼教部）编纂系统-万能工匠儿童创造力培养指导手册.docx下载成功

# %%
path = 'ftp://ftp3.dc2.fzyun.io:21/FounderDeployPackage/dongyan/word/bug/（幼教部）编纂系统-万能工匠儿童创造力培养指导手册.docx'
path.split(':21')
# Out:
# ['ftp://ftp3.dc2.fzyun.io',
#  '/FounderDeployPackage/dongyan/word/bug/（幼教部）编纂系统-万能工匠儿童创造力培养指导手册.docx']

# %%
traverse(r'C:\Users\Zhao.LJ\Downloads\20200916')
# Out:
# max datetime 2020-09-16 22:22:39

# %%
max_datetime = datetime.datetime(2020, 8, 18, 0, 0, 0)
print(max_datetime)
# Out:
# 2020-08-18 00:00:00
