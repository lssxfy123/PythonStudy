# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())  ## 扁平化，卷积+池化后，已提取了图片的特征信息，不再需要图片的空间信息
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\envs\udacity\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\envs\udacity\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\envs\udacity\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 39s - loss: 1.5703 - acc: 0.4352 - val_loss: 1.3554 - val_acc: 0.4958
#
# Epoch 00001: val_loss improved from inf to 1.35544, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 41s - loss: 1.2380 - acc: 0.5584 - val_loss: 1.2711 - val_acc: 0.5336
#
# Epoch 00002: val_loss improved from 1.35544 to 1.27106, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 39s - loss: 1.1197 - acc: 0.6065 - val_loss: 1.3356 - val_acc: 0.5360
#
# Epoch 00003: val_loss did not improve from 1.27106
# Epoch 4/100
#  - 38s - loss: 1.0563 - acc: 0.6291 - val_loss: 0.9729 - val_acc: 0.6630
#
# Epoch 00004: val_loss improved from 1.27106 to 0.97293, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 39s - loss: 1.0117 - acc: 0.6469 - val_loss: 0.9718 - val_acc: 0.6590
#
# Epoch 00005: val_loss improved from 0.97293 to 0.97177, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 38s - loss: 0.9914 - acc: 0.6565 - val_loss: 1.0070 - val_acc: 0.6578
#
# Epoch 00006: val_loss did not improve from 0.97177
# Epoch 7/100
#  - 38s - loss: 0.9824 - acc: 0.6651 - val_loss: 0.9302 - val_acc: 0.6788
#
# Epoch 00007: val_loss improved from 0.97177 to 0.93015, saving model to model.weights.best.hdf5
# Epoch 8/100
#  - 38s - loss: 0.9722 - acc: 0.6696 - val_loss: 0.9350 - val_acc: 0.6976
#
# Epoch 00008: val_loss did not improve from 0.93015
# Epoch 9/100
#  - 36s - loss: 0.9665 - acc: 0.6713 - val_loss: 0.8914 - val_acc: 0.6934
#
# Epoch 00009: val_loss improved from 0.93015 to 0.89139, saving model to model.weights.best.hdf5
# Epoch 10/100
#  - 38s - loss: 0.9683 - acc: 0.6727 - val_loss: 0.8835 - val_acc: 0.6980
#
# Epoch 00010: val_loss improved from 0.89139 to 0.88352, saving model to model.weights.best.hdf5
# Epoch 11/100
#  - 39s - loss: 0.9829 - acc: 0.6716 - val_loss: 0.9058 - val_acc: 0.6968
#
# Epoch 00011: val_loss did not improve from 0.88352
# Epoch 12/100
#  - 38s - loss: 0.9957 - acc: 0.6673 - val_loss: 1.1531 - val_acc: 0.6178
#
# Epoch 00012: val_loss did not improve from 0.88352
# Epoch 13/100
#  - 39s - loss: 1.0063 - acc: 0.6666 - val_loss: 1.0847 - val_acc: 0.6342
#
# Epoch 00013: val_loss did not improve from 0.88352
# Epoch 14/100
#  - 37s - loss: 1.0205 - acc: 0.6599 - val_loss: 1.2781 - val_acc: 0.6548
#
# Epoch 00014: val_loss did not improve from 0.88352
# Epoch 15/100
#  - 39s - loss: 1.0412 - acc: 0.6547 - val_loss: 0.9707 - val_acc: 0.6720
#
# Epoch 00015: val_loss did not improve from 0.88352
# Epoch 16/100
#  - 39s - loss: 1.0620 - acc: 0.6512 - val_loss: 1.4448 - val_acc: 0.5612
#
# Epoch 00016: val_loss did not improve from 0.88352
# Epoch 17/100
#  - 39s - loss: 1.0699 - acc: 0.6463 - val_loss: 1.1565 - val_acc: 0.6484
#
# Epoch 00017: val_loss did not improve from 0.88352
# Epoch 18/100
#  - 38s - loss: 1.0945 - acc: 0.6405 - val_loss: 1.6627 - val_acc: 0.6416
#
# Epoch 00018: val_loss did not improve from 0.88352
# Epoch 19/100
#  - 36s - loss: 1.1047 - acc: 0.6353 - val_loss: 0.9518 - val_acc: 0.6946
#
# Epoch 00019: val_loss did not improve from 0.88352
# Epoch 20/100
#  - 39s - loss: 1.1368 - acc: 0.6291 - val_loss: 1.3234 - val_acc: 0.6252
#
# Epoch 00020: val_loss did not improve from 0.88352
# Epoch 21/100
#  - 37s - loss: 1.1588 - acc: 0.6182 - val_loss: 1.6584 - val_acc: 0.5992
#
# Epoch 00021: val_loss did not improve from 0.88352
# Epoch 22/100
#  - 36s - loss: 1.1826 - acc: 0.6133 - val_loss: 1.0492 - val_acc: 0.6528
#
# Epoch 00022: val_loss did not improve from 0.88352
# Epoch 23/100
#  - 36s - loss: 1.2104 - acc: 0.6048 - val_loss: 1.2242 - val_acc: 0.6760
#
# Epoch 00023: val_loss did not improve from 0.88352
# Epoch 24/100
#  - 36s - loss: 1.2228 - acc: 0.6012 - val_loss: 1.2155 - val_acc: 0.5922
#
# Epoch 00024: val_loss did not improve from 0.88352
# Epoch 25/100
#  - 36s - loss: 1.2188 - acc: 0.5994 - val_loss: 1.2104 - val_acc: 0.5798
#
# Epoch 00025: val_loss did not improve from 0.88352
# Epoch 26/100
#  - 36s - loss: 1.2389 - acc: 0.5894 - val_loss: 1.1027 - val_acc: 0.6242
#
# Epoch 00026: val_loss did not improve from 0.88352
# Epoch 27/100
#  - 38s - loss: 1.2474 - acc: 0.5881 - val_loss: 1.0999 - val_acc: 0.6488
#
# Epoch 00027: val_loss did not improve from 0.88352
# Epoch 28/100
#  - 38s - loss: 1.2603 - acc: 0.5827 - val_loss: 1.4081 - val_acc: 0.5148
#
# Epoch 00028: val_loss did not improve from 0.88352
# Epoch 29/100
#  - 39s - loss: 1.2910 - acc: 0.5740 - val_loss: 1.8407 - val_acc: 0.4986
#
# Epoch 00029: val_loss did not improve from 0.88352
# Epoch 30/100
#  - 40s - loss: 1.3010 - acc: 0.5699 - val_loss: 1.3718 - val_acc: 0.5454
#
# Epoch 00030: val_loss did not improve from 0.88352
# Epoch 31/100
#  - 38s - loss: 1.3110 - acc: 0.5653 - val_loss: 1.9661 - val_acc: 0.4592
#
# Epoch 00031: val_loss did not improve from 0.88352
# Epoch 32/100
#  - 38s - loss: 1.3350 - acc: 0.5612 - val_loss: 1.1146 - val_acc: 0.6192
#
# Epoch 00032: val_loss did not improve from 0.88352
# Epoch 33/100
#  - 39s - loss: 1.3540 - acc: 0.5538 - val_loss: 1.2017 - val_acc: 0.6084
#
# Epoch 00033: val_loss did not improve from 0.88352
# Epoch 34/100
#  - 41s - loss: 1.3726 - acc: 0.5466 - val_loss: 2.0037 - val_acc: 0.5386
#
# Epoch 00034: val_loss did not improve from 0.88352
# Epoch 35/100
#  - 42s - loss: 1.3941 - acc: 0.5387 - val_loss: 1.1937 - val_acc: 0.6118
#
# Epoch 00035: val_loss did not improve from 0.88352
# Epoch 36/100
#  - 41s - loss: 1.3941 - acc: 0.5368 - val_loss: 1.2400 - val_acc: 0.5684
#
# Epoch 00036: val_loss did not improve from 0.88352
# Epoch 37/100
#  - 42s - loss: 1.4147 - acc: 0.5287 - val_loss: 1.3003 - val_acc: 0.5674
#
# Epoch 00037: val_loss did not improve from 0.88352
# Epoch 38/100
#  - 41s - loss: 1.4315 - acc: 0.5251 - val_loss: 1.2445 - val_acc: 0.5698
#
# Epoch 00038: val_loss did not improve from 0.88352
# Epoch 39/100
#  - 41s - loss: 1.4503 - acc: 0.5179 - val_loss: 1.1264 - val_acc: 0.6160
#
# Epoch 00039: val_loss did not improve from 0.88352
# Epoch 40/100
#  - 42s - loss: 1.4563 - acc: 0.5189 - val_loss: 1.2690 - val_acc: 0.5670
#
# Epoch 00040: val_loss did not improve from 0.88352
# Epoch 41/100
#  - 38s - loss: 1.4771 - acc: 0.5086 - val_loss: 1.3615 - val_acc: 0.5368
#
# Epoch 00041: val_loss did not improve from 0.88352
# Epoch 42/100
#  - 38s - loss: 1.4728 - acc: 0.5066 - val_loss: 1.2673 - val_acc: 0.5686
#
# Epoch 00042: val_loss did not improve from 0.88352
# Epoch 43/100
#  - 39s - loss: 1.4776 - acc: 0.5091 - val_loss: 1.2673 - val_acc: 0.5532
#
# Epoch 00043: val_loss did not improve from 0.88352
# Epoch 44/100
#  - 39s - loss: 1.4764 - acc: 0.5038 - val_loss: 1.4609 - val_acc: 0.5298
#
# Epoch 00044: val_loss did not improve from 0.88352
# Epoch 45/100
#  - 39s - loss: 1.4870 - acc: 0.4986 - val_loss: 1.3111 - val_acc: 0.5362
#
# Epoch 00045: val_loss did not improve from 0.88352
# Epoch 46/100
#  - 40s - loss: 1.4886 - acc: 0.5003 - val_loss: 1.4061 - val_acc: 0.5140
#
# Epoch 00046: val_loss did not improve from 0.88352
# Epoch 47/100
#  - 39s - loss: 1.5195 - acc: 0.4903 - val_loss: 1.3632 - val_acc: 0.5326
#
# Epoch 00047: val_loss did not improve from 0.88352
# Epoch 48/100
#  - 39s - loss: 1.5268 - acc: 0.4871 - val_loss: 1.4471 - val_acc: 0.5186
#
# Epoch 00048: val_loss did not improve from 0.88352
# Epoch 49/100
#  - 40s - loss: 1.5258 - acc: 0.4840 - val_loss: 1.2938 - val_acc: 0.5604
#
# Epoch 00049: val_loss did not improve from 0.88352
# Epoch 50/100
#  - 41s - loss: 1.5337 - acc: 0.4823 - val_loss: 1.4278 - val_acc: 0.5064
#
# Epoch 00050: val_loss did not improve from 0.88352
# Epoch 51/100
#  - 42s - loss: 1.5465 - acc: 0.4826 - val_loss: 1.4546 - val_acc: 0.4636
#
# Epoch 00051: val_loss did not improve from 0.88352
# Epoch 52/100
#  - 42s - loss: 1.5638 - acc: 0.4725 - val_loss: 2.0083 - val_acc: 0.4932
#
# Epoch 00052: val_loss did not improve from 0.88352
# Epoch 53/100
#  - 41s - loss: 1.5863 - acc: 0.4676 - val_loss: 1.5884 - val_acc: 0.4516
#
# Epoch 00053: val_loss did not improve from 0.88352
# Epoch 54/100
#  - 39s - loss: 1.6005 - acc: 0.4630 - val_loss: 1.3488 - val_acc: 0.5314
#
# Epoch 00054: val_loss did not improve from 0.88352
# Epoch 55/100
#  - 37s - loss: 1.6046 - acc: 0.4570 - val_loss: 1.6410 - val_acc: 0.4394
#
# Epoch 00055: val_loss did not improve from 0.88352
# Epoch 56/100
#  - 37s - loss: 1.6187 - acc: 0.4479 - val_loss: 3.2572 - val_acc: 0.3602
#
# Epoch 00056: val_loss did not improve from 0.88352
# Epoch 57/100
#  - 37s - loss: 1.6118 - acc: 0.4538 - val_loss: 1.7169 - val_acc: 0.5052
#
# Epoch 00057: val_loss did not improve from 0.88352
# Epoch 58/100
#  - 39s - loss: 1.6294 - acc: 0.4466 - val_loss: 1.4354 - val_acc: 0.5150
#
# Epoch 00058: val_loss did not improve from 0.88352
# Epoch 59/100
#  - 38s - loss: 1.6270 - acc: 0.4455 - val_loss: 1.5194 - val_acc: 0.4814
#
# Epoch 00059: val_loss did not improve from 0.88352
# Epoch 60/100
#  - 38s - loss: 1.6421 - acc: 0.4413 - val_loss: 1.3703 - val_acc: 0.5366
#
# Epoch 00060: val_loss did not improve from 0.88352
# Epoch 61/100
#  - 37s - loss: 1.6468 - acc: 0.4356 - val_loss: 1.4045 - val_acc: 0.5208
#
# Epoch 00061: val_loss did not improve from 0.88352
# Epoch 62/100
#  - 40s - loss: 1.6492 - acc: 0.4378 - val_loss: 1.3147 - val_acc: 0.5520
#
# Epoch 00062: val_loss did not improve from 0.88352
# Epoch 63/100
#  - 40s - loss: 1.6515 - acc: 0.4353 - val_loss: 1.5453 - val_acc: 0.4388
#
# Epoch 00063: val_loss did not improve from 0.88352
# Epoch 64/100
#  - 37s - loss: 1.6547 - acc: 0.4326 - val_loss: 2.2990 - val_acc: 0.4158
#
# Epoch 00064: val_loss did not improve from 0.88352
# Epoch 65/100
#  - 38s - loss: 1.6568 - acc: 0.4321 - val_loss: 2.4177 - val_acc: 0.3602
#
# Epoch 00065: val_loss did not improve from 0.88352
# Epoch 66/100
#  - 39s - loss: 1.6715 - acc: 0.4263 - val_loss: 1.4737 - val_acc: 0.4768
#
# Epoch 00066: val_loss did not improve from 0.88352
# Epoch 67/100
#  - 40s - loss: 1.6753 - acc: 0.4266 - val_loss: 2.3033 - val_acc: 0.4526
#
# Epoch 00067: val_loss did not improve from 0.88352
# Epoch 68/100
#  - 39s - loss: 1.6846 - acc: 0.4245 - val_loss: 1.4691 - val_acc: 0.4852
#
# Epoch 00068: val_loss did not improve from 0.88352
# Epoch 69/100
#  - 38s - loss: 1.6823 - acc: 0.4292 - val_loss: 1.4070 - val_acc: 0.5050
#
# Epoch 00069: val_loss did not improve from 0.88352
# Epoch 70/100
#  - 40s - loss: 1.6733 - acc: 0.4272 - val_loss: 1.5421 - val_acc: 0.4676
#
# Epoch 00070: val_loss did not improve from 0.88352
# Epoch 71/100
#  - 41s - loss: 1.6838 - acc: 0.4256 - val_loss: 1.4404 - val_acc: 0.5018
#
# Epoch 00071: val_loss did not improve from 0.88352
# Epoch 72/100
#  - 41s - loss: 1.6748 - acc: 0.4236 - val_loss: 1.4737 - val_acc: 0.4774
#
# Epoch 00072: val_loss did not improve from 0.88352
# Epoch 73/100
#  - 40s - loss: 1.6792 - acc: 0.4178 - val_loss: 1.5833 - val_acc: 0.4676
#
# Epoch 00073: val_loss did not improve from 0.88352
# Epoch 74/100
#  - 37s - loss: 1.6718 - acc: 0.4213 - val_loss: 1.6699 - val_acc: 0.4694
#
# Epoch 00074: val_loss did not improve from 0.88352
# Epoch 75/100
#  - 37s - loss: 1.6993 - acc: 0.4152 - val_loss: 1.6236 - val_acc: 0.4250
#
# Epoch 00075: val_loss did not improve from 0.88352
# Epoch 76/100
#  - 37s - loss: 1.6880 - acc: 0.4179 - val_loss: 1.4121 - val_acc: 0.5206
#
# Epoch 00076: val_loss did not improve from 0.88352
# Epoch 77/100
#  - 37s - loss: 1.7019 - acc: 0.4137 - val_loss: 3.1515 - val_acc: 0.2430
#
# Epoch 00077: val_loss did not improve from 0.88352
# Epoch 78/100
#  - 37s - loss: 1.7015 - acc: 0.4146 - val_loss: 1.8929 - val_acc: 0.3752
#
# Epoch 00078: val_loss did not improve from 0.88352
# Epoch 79/100
#  - 38s - loss: 1.6979 - acc: 0.4118 - val_loss: 2.4912 - val_acc: 0.2524
#
# Epoch 00079: val_loss did not improve from 0.88352
# Epoch 80/100
#  - 38s - loss: 1.7000 - acc: 0.4130 - val_loss: 1.5391 - val_acc: 0.4536
#
# Epoch 00080: val_loss did not improve from 0.88352
# Epoch 81/100
#  - 39s - loss: 1.7257 - acc: 0.4048 - val_loss: 3.7126 - val_acc: 0.2688
#
# Epoch 00081: val_loss did not improve from 0.88352
# Epoch 82/100
#  - 40s - loss: 1.7210 - acc: 0.4059 - val_loss: 1.4793 - val_acc: 0.4708
#
# Epoch 00082: val_loss did not improve from 0.88352
# Epoch 83/100
#  - 38s - loss: 1.7287 - acc: 0.4002 - val_loss: 1.6040 - val_acc: 0.4384
#
# Epoch 00083: val_loss did not improve from 0.88352
# Epoch 84/100
#  - 38s - loss: 1.7428 - acc: 0.3968 - val_loss: 1.8177 - val_acc: 0.3786
#
# Epoch 00084: val_loss did not improve from 0.88352
# Epoch 85/100
#  - 38s - loss: 1.7467 - acc: 0.3964 - val_loss: 1.6709 - val_acc: 0.4026
#
# Epoch 00085: val_loss did not improve from 0.88352
# Epoch 86/100
#  - 39s - loss: 1.7599 - acc: 0.3903 - val_loss: 1.6804 - val_acc: 0.3814
#
# Epoch 00086: val_loss did not improve from 0.88352
# Epoch 87/100
#  - 38s - loss: 1.7551 - acc: 0.3948 - val_loss: 4.2777 - val_acc: 0.3128
#
# Epoch 00087: val_loss did not improve from 0.88352
# Epoch 88/100
#  - 37s - loss: 1.7622 - acc: 0.3880 - val_loss: 1.6305 - val_acc: 0.4338
#
# Epoch 00088: val_loss did not improve from 0.88352
# Epoch 89/100
#  - 36s - loss: 1.7695 - acc: 0.3845 - val_loss: 1.6822 - val_acc: 0.4244
#
# Epoch 00089: val_loss did not improve from 0.88352
# Epoch 90/100
#  - 37s - loss: 1.7661 - acc: 0.3831 - val_loss: 1.6672 - val_acc: 0.4040
#
# Epoch 00090: val_loss did not improve from 0.88352
# Epoch 91/100
#  - 37s - loss: 1.7762 - acc: 0.3806 - val_loss: 1.5779 - val_acc: 0.4224
#
# Epoch 00091: val_loss did not improve from 0.88352
# Epoch 92/100
#  - 37s - loss: 1.7841 - acc: 0.3823 - val_loss: 2.0433 - val_acc: 0.3438
#
# Epoch 00092: val_loss did not improve from 0.88352
# Epoch 93/100
#  - 37s - loss: 1.7877 - acc: 0.3791 - val_loss: 1.6456 - val_acc: 0.4236
#
# Epoch 00093: val_loss did not improve from 0.88352
# Epoch 94/100
#  - 38s - loss: 1.7993 - acc: 0.3756 - val_loss: 1.5447 - val_acc: 0.4496
#
# Epoch 00094: val_loss did not improve from 0.88352
# Epoch 95/100
#  - 40s - loss: 1.8087 - acc: 0.3690 - val_loss: 1.8273 - val_acc: 0.3838
#
# Epoch 00095: val_loss did not improve from 0.88352
# Epoch 96/100
#  - 42s - loss: 1.8225 - acc: 0.3664 - val_loss: 1.6764 - val_acc: 0.3836
#
# Epoch 00096: val_loss did not improve from 0.88352
# Epoch 97/100
#  - 47s - loss: 1.8086 - acc: 0.3642 - val_loss: 1.7772 - val_acc: 0.3910
#
# Epoch 00097: val_loss did not improve from 0.88352
# Epoch 98/100
#  - 39s - loss: 1.8106 - acc: 0.3655 - val_loss: 1.7843 - val_acc: 0.3434
#
# Epoch 00098: val_loss did not improve from 0.88352
# Epoch 99/100
#  - 40s - loss: 1.8182 - acc: 0.3569 - val_loss: 2.0017 - val_acc: 0.3258
#
# Epoch 00099: val_loss did not improve from 0.88352
# Epoch 100/100
#  - 37s - loss: 1.8158 - acc: 0.3545 - val_loss: 1.5797 - val_acc: 0.4258
#
# Epoch 00100: val_loss did not improve from 0.88352

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6992

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
